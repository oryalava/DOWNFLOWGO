# %% [markdown]
# # Welcome to DOWNFLOWGO 🌋
# ---
#
# A number of numerical models exist to support lava flow modeling (see review by Dietterich et al. [2017]). Here, we combine the stochastic model DOWNFLOW [Favalli et al. 2005](https://doi.org/10.1029/2004gl021718) with the deterministic model FLOWGO [Harris and Rowland 2001](https://doi.org/10.1007/s004450000120) to support hazard assessment at Piton de la Fournaise , mainly.
#
# DOWNFLOW provides the most likely lava flow paths, including the LoSD and area of coverage. For responding to current crises at Piton de la Fournaise, this model was calibrated by fitting the output flow coverage to the actual areas of all flow fields since 2016 [Chevrel et al. 2021](https://doi.org/10.5194/nhess-21-2355-2021). DOWNFLOW must be calibrated (dh and N parameters) for you volcano.
#
# FLOWGO calculates the runout distance of a lava flow along a slope line for a given effusion rate [Harris and Rowland 2001](https://doi.org/10.1007/s004450000120). It is 1-D model adapted for cooling-limited basaltic lava flow in a channel of uniform depth that, once calibrated with a suitable models and input parameters, only needs the slope from the vent along the steepest descent line and a discharge rate as its source terms. The code is now an open access python library : [PyFLOwGO](https://github.com/pyflowgo/pyflowgo.git) presented in [Chevrel et al. 2018](https://doi.org/10.1016/j.cageo.2017.11.009).
#
# FLOWGO source terms must be adapted accordingly to your lava flow. See exemples on Earth: Hawaiʻi, (Harris et al., 2022; Harris & Rowland, 2001, 2015; Mossoux et al., 2016; Riker et al., 2009; Robert et al., 2014; Rowland et al., 2005; Chevrel et al., 2018; Thompson and Ramsey, 2021), Italy (Harris et al., 2007, 2011; Wright et al., 2008) ; Kamchatka (Ramsey et al. 2019); Mt Cameroon (Wantim et al. 2013); D.R. Congo (Mossoux et al. 2016), Galapagos (Rowland et al. 2003) La Reunion (Chevrel et al., 2018, 2022; Harris et al., 2016, 2019; Peltier et al., 2022; Rhéty et al., 2017) and on other planets (see also next session): Mars (Flynn et al., 2022; Rowland et al., 2004) Mercury (Vetere et al. 2017) ; Moon (Lev et al. 2021) and Venus Flynn et al. (2023).
#
# To use this package you must cite these 3 publications: [Chevrel et al. 2022](https://doi.org/10.30909/vol.05.02.313334), [Favalli 2005](https://doi.org/10.30909/vol.05.02.313334) and [Harris and Rowland 2001](https://doi.org/10.1007/s004450000120):
#
# Chevrel MO, Harris A, Peltier A, Villeneuve N, Coppola D, Gouhier M, Drenne S. (2022) Volcanic crisis management supported by near real time lava flow hazard assessment at Piton de la Fournaise, Volcanica 5(2), pp. 313–334. https://doi.org/10.30909/vol.05.02.313334
#
# Harris, A. J. L. and S. Rowland (2001). “FLOWGO: a kinematic thermo-rheological model for lava flowing in a channel”. Bulletin of Volcanology 63(1), pages 20–44. issn: 1432-0819. https://doi.org/10.1007/s004450000120.
#
# Favalli, M. et al. (2005). “Forecasting lava flow paths by a stochastic approach”. Geophysical Research Letters 32(3). issn: 0094- 8276. https://doi.org/10.1029/2004gl021718.**

# %%
import time
import downflowgo.datamanager as datamanager
from downflowgo.all_for_grid import grid_maker_reader
from downflowgo.config_loader import Config
from downflowgo.perf_timer import runtime
from downflowgo.runner import Runner
from downflowgo.mapping import Mapping
from pandas import DataFrame # Pour affcher proprement les tableaux dans les prints
from IPython.display import clear_output # Nettoie les cellules de Jupyter

# %%
# Start the timer
start_time = time.time()

# %%
# Initializes the configuration
config = Config()

# %%
# Choose the language of the map
config.language = "FR"

# %% [markdown]
# ## General configuration
# `mode` can be:
#  - **downflowgo**
#  - **downflow**
#
# `grid_mode` can be:
#  - **yes**
#     > In [**`all_for_grid.py`**](downflowgo/all_for_grid.py): **DOWNFLOWGO** defines an area around the pixel containing the vent location and discretizes it according to the user-specified resolution. A **DOWFLOW** model is then run for each vent defined in the grid. The model subsequently constructs a map showing the most probable lava flow paths.
#  - **no**
#
# `delete_existing` on **yes** will delete all results in the folder `path_to_folder`.

# %%
# [config_general]
config.mode = "downflowgo"
config.grid_mode = "no"
config.delete_existing = "yes" # Delete existing results?

# %%
# [paths]
config.path_to_eruptions = "./assets/outputs" # Eruption folder
config.dem = "./assets/test/DEM/MNT-post-20220919_5m.asc"
config.csv_vent_file = "0"

# If grid mode is activate else None
config.grid_csv = "./Vent_grid.csv"

# [pyflowgo]
config.json_input = "./assets/test/PdF_template.json"

config.validate_path()

# %%
file_opener = datamanager.DataManager(config)
# Out:
# DEM is valid.

# %%
# [downflow]
config.name_vent = "pixel_center_2"
config.easting = 369082.7
config.northing = 7647204.29
config.DH = 2
config.n = 10000
config.slope_step = 10
config.epsg_code = 32740

# [pyflowgo]
config.effusion_rates_input = "5,30,5"
effusion_rates = config.set_effusion_rate(config.effusion_rates_input)
config.show(effusion_rates)
# Out:
# first_eff_rate: 5
# last_eff_rate: 30
# step_eff_rate: 5

# %%
# Writes a csv file with the position of the vent in the config file
file_opener.csv_vent_writer()
# Out:
# [INFO] Csv file used : /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/csv_vent_file.csv
# CSV format is valid.

# %%
csv_data = file_opener.csv_vent_reader()

# %%
# [grid_parameters]
if config.grid_mode == 'yes':
    config.ventgrid_size = 375
    config.ventgrid_resolution = 375
    config.dem_resolution = 5
    config.path_to_grid_folder = config.set_path_to_grid_folder() # *Need path_to_eruptions and name_vent
    config.show(config.grid_mode_summary()) 
else:
    print("No grid mode.")
# Out:
# No grid mode.

# %%
if config.grid_mode == 'yes':
    # Make a new csv file with the location of each new vent
    grid = grid_maker_reader(csv_data, config)
else:
    if not config.from_vent:
        # Read the new csv
        csv_data = file_opener.csv_vent_reader()
# Out:
# Csv file used : /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/csv_vent_file.csv
# Grid created from csv : /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/pixel_center_res375_ventgrid_coordinates.csv

# %%
# Read the new csv
csv_data = file_opener.csv_vent_reader()
print(DataFrame(csv_data))
# Out:
#           flow_id            X             Y
# 0  368872_7646861  368872.4729  7646861.5718
# 1  368872_7647236  368872.4729  7647236.5718
# 2  369247_7646861  369247.4729  7646861.5718
# 3  369247_7647236  369247.4729  7647236.5718

# %%
runner = Runner(config)

# %%
# Start the loop to run downflowgo for each row in the csv file
for data in csv_data:
    runner.run_model(data)
    clear_output(wait=True)
# Out:
# Loading grid data:  /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/DEM/MNT-post-20220919_5m.asc
# Algo:  0
# Loading grid '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/DEM/MNT-post-20220919_5m.asc'.
# DEM header loaded.
# Matrix loaded...
# 				 -> Grid loaded (3193 x 2305):            1.18 seconds.
# Grid allocated.
# Writing dem_filled_DH0.001_N1000.asc ...  done.
#
# Total elapsed time: 3.03 seconds.
# Algo:  0
# Profile dl =10.000000
# Profile dl =10.000000
# Loading grid '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/dem_filled_DH0.001_N1000.asc'.
# DEM header loaded.
# 				 -> flow routines:           1.37 seconds.
# 				 ... saving grid:             1.66 seconds.
# ************************ DOWNFLOW filled DEM done *********
# Loading grid data:  /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/dem_filled_DH0.001_N1000.asc
# Matrix loaded...
# 				 -> Grid loaded (3193 x 2305):            1.30 seconds.
# Grid allocated.
# Writing sim.asc ...  done.
#
# Total elapsed time: 2.34 seconds.
# 				 -> flow routines:           1.33 seconds.
# 				 ... saving grid:             1.00 seconds.
#  Cropped simulation saved in Geotiff at '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/profile_369247_7647236_dH001_n1_sim.tif'
# ************************ DOWNFLOW LoSD done *********
# Loading grid data:  /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/DEM/MNT-post-20220919_5m.asc
# Algo:  0
# Loading grid '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/DEM/MNT-post-20220919_5m.asc'.
# DEM header loaded.
# Matrix loaded...
# 				 -> Grid loaded (3193 x 2305):            1.20 seconds.
# Grid allocated.
# Writing sim.asc ...  done.
#
# Total elapsed time: 6.22 seconds.
# 				 -> flow routines:           5.26 seconds.
# 				 ... saving grid:             0.97 seconds.
# ************************ DOWNFLOW probabilities done *********
#  Cropped simulation saved in Geotiff at '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/sim_369247_7647236.tif'
# *********** Simulation paths done and saved in: /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/sim_369247_7647236.tif *********
# **************** End of DOWNFLOW  369247_7647236 *********

# %%
if config.grid_mode == 'yes':
    runner.run_gridmode(grid)
else:
    print("No grid mode.")
# Out:
# **************** Path stacking done *********
# ++++++++++++++++++ Losd file is saved in shape format at: '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/pixel_center_pathfinder.shp'+++++++++++++++++
# **************** Path finder done :/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/pixel_center_pathfinder.shp *********
# Volume conservation
# channel_depth =0.7169999999999994
# Vmean (m/s)= 1.749798829543954
# distance from vent (m) = 0.0
# phi= 0.10449945908436763
# Tcore= 1387.0658215026347
# Vmean (m/s)= 1.6936883779588043
# distance from vent (m) = 10.0
# phi= 0.10501490943003627
# Tcore= 1386.9789478488703
# Vmean (m/s)= 1.6189110363105075
# distance from vent (m) = 20.0
# phi= 0.10555341313348955
# Tcore= 1386.8881887977266
# Vmean (m/s)= 1.5306773241592877
# distance from vent (m) = 30.0
# phi= 0.10612202493245947
# Tcore= 1386.792355348462
# Vmean (m/s)= 1.4816493866992575
# distance from vent (m) = 40.0
# phi= 0.1067088796001075
# Tcore= 1386.693447258409
# Vmean (m/s)= 1.4565898115619638
# distance from vent (m) = 50.0
# phi= 0.10730549187748883
# Tcore= 1386.5928946273896
# Vmean (m/s)= 1.3664121756219891
# distance from vent (m) = 60.0
# phi= 0.10794040338255824
# Tcore= 1386.4858870703554
# Vmean (m/s)= 1.2693877716680213
# distance from vent (m) = 70.0
# phi= 0.10862260017693458
# Tcore= 1386.3709100825392
# Vmean (m/s)= 1.186024032153357
# distance from vent (m) = 80.0
# phi= 0.1093515809693095
# Tcore= 1386.24804815124
# Vmean (m/s)= 1.1419057861512782
# distance from vent (m) = 90.0
# phi= 0.11010802102867705
# Tcore= 1386.1205582535938
# Vmean (m/s)= 1.0716478915356373
# distance from vent (m) = 100.0
# phi= 0.11091293261882494
# Tcore= 1385.9848989968273
# Vmean (m/s)= 0.9667672018051041
# distance from vent (m) = 110.0
# phi= 0.11180337782739347
# Tcore= 1385.8348239616753
# Vmean (m/s)= 0.9081127588617783
# distance from vent (m) = 120.0
# phi= 0.11275017642492216
# Tcore= 1385.675251164339
# Vmean (m/s)= 0.8880880277311002
# distance from vent (m) = 130.0
# phi= 0.1137177763144942
# Tcore= 1385.5121725312652
# Vmean (m/s)= 0.8570264913144761
# distance from vent (m) = 140.0
# phi= 0.11471968135167339
# Tcore= 1385.3433121317405
# Vmean (m/s)= 0.8129197526750367
# distance from vent (m) = 150.0
# phi= 0.11577489408157565
# Tcore= 1385.1654672896223
# Vmean (m/s)= 0.7718656176546779
# distance from vent (m) = 160.0
# phi= 0.11688516924708582
# Tcore= 1384.9783422617272
# Vmean (m/s)= 0.7642431735624798
# distance from vent (m) = 170.0
# phi= 0.11800608513353193
# Tcore= 1384.7894238538993
# Vmean (m/s)= 0.8109348887090535
# distance from vent (m) = 180.0
# phi= 0.1190630500930189
# Tcore= 1384.611283692188
# Vmean (m/s)= 0.8469607604583144
# distance from vent (m) = 190.0
# phi= 0.12007544609272687
# Tcore= 1384.4406551529114
# Vmean (m/s)= 0.8523815793464977
# distance from vent (m) = 200.0
# phi= 0.12108126547064742
# Tcore= 1384.2711350330371
# Vmean (m/s)= 0.884148777568351
# distance from vent (m) = 210.0
# phi= 0.1220512576199581
# Tcore= 1384.1076532101197
# Vmean (m/s)= 0.9258640082062066
# distance from vent (m) = 220.0
# phi= 0.12297801045258208
# Tcore= 1383.9514589124865
# Vmean (m/s)= 0.933365520012787
# distance from vent (m) = 230.0
# phi= 0.12389723906849984
# Tcore= 1383.7965327412644
# Vmean (m/s)= 0.9188283942801146
# distance from vent (m) = 240.0
# phi= 0.12483057952677576
# Tcore= 1383.6392281696449
# Vmean (m/s)= 0.8927855158987584
# distance from vent (m) = 250.0
# phi= 0.12579050760758792
# Tcore= 1383.4774425380474
# Vmean (m/s)= 0.8528887879109538
# distance from vent (m) = 260.0
# phi= 0.12679442482863662
# Tcore= 1383.30824300641
# Vmean (m/s)= 0.818794882409828
# distance from vent (m) = 270.0
# phi= 0.1278392868243204
# Tcore= 1383.1321426700588
# Vmean (m/s)= 0.7772847179259545
# distance from vent (m) = 280.0
# phi= 0.12893889443881537
# Tcore= 1382.9468155440204
# Vmean (m/s)= 0.752813948241985
# distance from vent (m) = 290.0
# phi= 0.130073479262473
# Tcore= 1382.7555933827298
# Vmean (m/s)= 0.7763685536692041
# distance from vent (m) = 300.0
# phi= 0.13117380621496183
# Tcore= 1382.5701450199508
# Vmean (m/s)= 0.8109137623055506
# distance from vent (m) = 310.0
# phi= 0.13222762477698638
# Tcore= 1382.3925351499468
# Vmean (m/s)= 0.806511878697458
# distance from vent (m) = 320.0
# phi= 0.13328685949422114
# Tcore= 1382.214012444795
# Vmean (m/s)= 0.7612550291055094
# distance from vent (m) = 330.0
# phi= 0.13440791644876585
# Tcore= 1382.0250702614446
# Vmean (m/s)= 0.7469959652548942
# distance from vent (m) = 340.0
# phi= 0.1355497990367708
# Tcore= 1381.8326181398706
# Vmean (m/s)= 0.7844951078008094
# distance from vent (m) = 350.0
# phi= 0.13663752183260325
# Tcore= 1381.6492940731573
# Vmean (m/s)= 0.8204241467731518
# distance from vent (m) = 360.0
# phi= 0.137677997387726
# Tcore= 1381.473933024541
# Vmean (m/s)= 0.8452612581407255
# distance from vent (m) = 370.0
# phi= 0.13868809265554113
# Tcore= 1381.3036922490667
# Vmean (m/s)= 0.8594920467503845
# distance from vent (m) = 380.0
# phi= 0.13968147809986317
# Tcore= 1381.1362677359787
# Vmean (m/s)= 0.8595102061396557
# distance from vent (m) = 390.0
# phi= 0.14067461743757628
# Tcore= 1380.9688847015327
# Vmean (m/s)= 0.8565922499397849
# distance from vent (m) = 400.0
# phi= 0.14167086373144974
# Tcore= 1380.80097802279
# Vmean (m/s)= 0.8335486198599742
# distance from vent (m) = 410.0
# phi= 0.14269401240084903
# Tcore= 1380.6285372358127
# Vmean (m/s)= 0.8006506358378543
# distance from vent (m) = 420.0
# phi= 0.14375834921517758
# Tcore= 1380.4491546266563
# Vmean (m/s)= 0.7938291077858979
# distance from vent (m) = 430.0
# phi= 0.1448314454927693
# Tcore= 1380.2682957034667
# Vmean (m/s)= 0.8096814379388685
# distance from vent (m) = 440.0
# phi= 0.1458835620033729
# Tcore= 1380.0909726960617
# Vmean (m/s)= 0.8125041413118612
# distance from vent (m) = 450.0
# phi= 0.14693182277639835
# Tcore= 1379.9142995320688
# Vmean (m/s)= 0.7940787657579573
# distance from vent (m) = 460.0
# phi= 0.14800381061899542
# Tcore= 1379.733627423766
# Vmean (m/s)= 0.7865135243910777
# distance from vent (m) = 470.0
# phi= 0.14908570442589503
# Tcore= 1379.5512857709177
# Vmean (m/s)= 0.7901359157324521
# distance from vent (m) = 480.0
# phi= 0.1501624399225901
# Tcore= 1379.3698134961937
# Vmean (m/s)= 0.8020833698498244
# distance from vent (m) = 490.0
# phi= 0.15122309443479878
# Tcore= 1379.1910514997542
# Vmean (m/s)= 0.8136634059258105
# distance from vent (m) = 500.0
# phi= 0.15226860890957386
# Tcore= 1379.0148411950167
# Vmean (m/s)= 0.8045149300994456
# distance from vent (m) = 510.0
# phi= 0.1533255943929541
# Tcore= 1378.8366975742224
# Vmean (m/s)= 0.8121505107497516
# distance from vent (m) = 520.0
# phi= 0.1543725274021432
# Tcore= 1378.6602481906511
# Vmean (m/s)= 0.8407913458431767
# distance from vent (m) = 530.0
# phi= 0.15538405274712713
# Tcore= 1378.4897663909348
# Vmean (m/s)= 0.8528048593724121
# distance from vent (m) = 540.0
# phi= 0.15638130375283765
# Tcore= 1378.3216903787365
# Vmean (m/s)= 0.8442051917896071
# distance from vent (m) = 550.0
# phi= 0.15738833599441135
# Tcore= 1378.1519658436398
# Vmean (m/s)= 0.8298579060866869
# distance from vent (m) = 560.0
# phi= 0.1584122918855494
# Tcore= 1377.9793890080548
# Vmean (m/s)= 0.820405887238477
# distance from vent (m) = 570.0
# phi= 0.15944763566742604
# Tcore= 1377.804892865042
# Vmean (m/s)= 0.8209537839972114
# distance from vent (m) = 580.0
# phi= 0.16048205406303795
# Tcore= 1377.6305526860062
# Vmean (m/s)= 0.828169621904196
# distance from vent (m) = 590.0
# phi= 0.1615073443879764
# Tcore= 1377.4577509458481
# Vmean (m/s)= 0.8200984988418207
# distance from vent (m) = 600.0
# phi= 0.16254234053404656
# Tcore= 1377.2833133931397
# Vmean (m/s)= 0.7974121522799426
# distance from vent (m) = 610.0
# phi= 0.16360611870744435
# Tcore= 1377.1040249369491
# Vmean (m/s)= 0.7839060335147784
# distance from vent (m) = 620.0
# phi= 0.16468771320899075
# Tcore= 1376.9217337288233
# Vmean (m/s)= 0.7747134752381393
# distance from vent (m) = 630.0
# phi= 0.16578170041384238
# Tcore= 1376.737353862837
# Vmean (m/s)= 0.7635309887982609
# distance from vent (m) = 640.0
# phi= 0.16689122164975526
# Tcore= 1376.550355901728
# Vmean (m/s)= 0.7552577164200829
# distance from vent (m) = 650.0
# phi= 0.16801245540146323
# Tcore= 1376.361383921103
# Vmean (m/s)= 0.7614387664139903
# distance from vent (m) = 660.0
# phi= 0.16912442137070516
# Tcore= 1376.1739739262869
# Vmean (m/s)= 0.7860460149944232
# distance from vent (m) = 670.0
# phi= 0.17020175708292049
# Tcore= 1375.9924004916438
# Vmean (m/s)= 0.807108679123707
# distance from vent (m) = 680.0
# phi= 0.17125109769579175
# Tcore= 1375.815545332171
# Vmean (m/s)= 0.8070186604616627
# distance from vent (m) = 690.0
# phi= 0.17230030310411723
# Tcore= 1375.6387129599814
# Vmean (m/s)= 0.794083006248048
# distance from vent (m) = 700.0
# phi= 0.1733661107122408
# Tcore= 1375.4590824642303
# Vmean (m/s)= 0.7814412535776697
# distance from vent (m) = 710.0
# phi= 0.17444866478046078
# Tcore= 1375.2766295313843
# Vmean (m/s)= 0.7723494816235207
# distance from vent (m) = 720.0
# phi= 0.17554352314578428
# Tcore= 1375.0921028405994
# Vmean (m/s)= 0.7645477924450645
# distance from vent (m) = 730.0
# phi= 0.17664913173855754
# Tcore= 1374.9057643137276
# Vmean (m/s)= 0.7441806003648633
# distance from vent (m) = 740.0
# phi= 0.17778432042317946
# Tcore= 1374.7144403781172
# Vmean (m/s)= 0.7124255828965699
# distance from vent (m) = 750.0
# phi= 0.1789691617598112
# Tcore= 1374.5147480180108
# Vmean (m/s)= 0.6958657364065013
# distance from vent (m) = 760.0
# phi= 0.18018153151219232
# Tcore= 1374.3104160372725
# Vmean (m/s)= 0.6892732388508203
# distance from vent (m) = 770.0
# phi= 0.18140502320753285
# Tcore= 1374.1042095717658
# Vmean (m/s)= 0.6787785493316738
# distance from vent (m) = 780.0
# phi= 0.18264686522661683
# Tcore= 1373.8949103550663
# Vmean (m/s)= 0.6752057664889399
# distance from vent (m) = 790.0
# phi= 0.1838948512847791
# Tcore= 1373.6845756261625
# Vmean (m/s)= 0.6723157513373978
# distance from vent (m) = 800.0
# phi= 0.18514778610369043
# Tcore= 1373.4734068364585
# Vmean (m/s)= 0.6653311282458088
# distance from vent (m) = 810.0
# phi= 0.1864133647310687
# Tcore= 1373.2601070677993
# Vmean (m/s)= 0.6572777060976763
# distance from vent (m) = 820.0
# phi= 0.18769390785447285
# Tcore= 1373.0442851930682
# Vmean (m/s)= 0.6491258784595394
# distance from vent (m) = 830.0
# phi= 0.1889899770431189
# Tcore= 1372.8258465657682
# Vmean (m/s)= 0.6437224041829432
# distance from vent (m) = 840.0
# phi= 0.19029642251287163
# Tcore= 1372.6056591270458
# Vmean (m/s)= 0.645007175205203
# distance from vent (m) = 850.0
# phi= 0.19159990887002404
# Tcore= 1372.3859704151662
# Vmean (m/s)= 0.6533521297364351
# distance from vent (m) = 860.0
# phi= 0.19288654912750414
# Tcore= 1372.1691209335684
# Vmean (m/s)= 0.6594404241866859
# distance from vent (m) = 870.0
# phi= 0.19416107094447446
# Tcore= 1371.9543138857643
# Vmean (m/s)= 0.6620516561752641
# distance from vent (m) = 880.0
# phi= 0.19543025595292052
# Tcore= 1371.7404063000713
# Vmean (m/s)= 0.6774108760107593
# distance from vent (m) = 890.0
# phi= 0.1966706304142046
# Tcore= 1371.531354424574
# Vmean (m/s)= 0.7196908372117266
# distance from vent (m) = 900.0
# phi= 0.19783864276603566
# Tcore= 1371.3344984102205
# Vmean (m/s)= 0.7765802622289821
# distance from vent (m) = 910.0
# phi= 0.19892184362195042
# Tcore= 1371.1519364682124
# Vmean (m/s)= 0.8198862214617032
# distance from vent (m) = 920.0
# phi= 0.1999483266836377
# Tcore= 1370.9789337050067
# Vmean (m/s)= 0.8531955739729628
# distance from vent (m) = 930.0
# phi= 0.20093505777978035
# Tcore= 1370.8126307112748
# Vmean (m/s)= 0.8971733810317943
# distance from vent (m) = 940.0
# phi= 0.20187390387085943
# Tcore= 1370.6543982240144
# Vmean (m/s)= 0.9401755774962859
# distance from vent (m) = 950.0
# phi= 0.2027702633817175
# Tcore= 1370.5033263963417
# Vmean (m/s)= 0.966267624051084
# distance from vent (m) = 960.0
# phi= 0.20364262158276578
# Tcore= 1370.3562997332435
# Vmean (m/s)= 0.9760565688503482
# distance from vent (m) = 970.0
# phi= 0.204506200427271
# Tcore= 1370.2107527369785
# Vmean (m/s)= 0.9705833144560458
# distance from vent (m) = 980.0
# phi= 0.20537439839916144
# Tcore= 1370.064427236098
# Vmean (m/s)= 0.9517439708509435
# distance from vent (m) = 990.0
# phi= 0.20625932751692272
# Tcore= 1369.915281879172
# Vmean (m/s)= 0.9164809923632038
# distance from vent (m) = 1000.0
# phi= 0.2071775779734926
# Tcore= 1369.760520566267
# Vmean (m/s)= 0.8601205854927503
# distance from vent (m) = 1010.0
# phi= 0.20815487009676412
# Tcore= 1369.5958084106594
# Vmean (m/s)= 0.7950289189943726
# distance from vent (m) = 1020.0
# phi= 0.2092107882048225
# Tcore= 1369.4178446845822
# Vmean (m/s)= 0.7474323545885654
# distance from vent (m) = 1030.0
# phi= 0.2103327814149317
# Tcore= 1369.2287447053502
# Vmean (m/s)= 0.7244985532071616
# distance from vent (m) = 1040.0
# phi= 0.21148955118333362
# Tcore= 1369.0337835084285
# Vmean (m/s)= 0.708045579113082
# distance from vent (m) = 1050.0
# phi= 0.21267256412310964
# Tcore= 1368.8343993050955
# Vmean (m/s)= 0.6972009139437064
# distance from vent (m) = 1060.0
# phi= 0.21387343805964645
# Tcore= 1368.6320048214095
# Vmean (m/s)= 0.7068595300673653
# distance from vent (m) = 1070.0
# phi= 0.21505777333051976
# Tcore= 1368.4323977532847
# Vmean (m/s)= 0.7271530252322717
# distance from vent (m) = 1080.0
# phi= 0.21620913921995336
# Tcore= 1368.2383473224813
# Vmean (m/s)= 0.732633959373866
# distance from vent (m) = 1090.0
# phi= 0.21735169867457518
# Tcore= 1368.045781122264
# Vmean (m/s)= 0.7240023201723906
# distance from vent (m) = 1100.0
# phi= 0.2185074137462272
# Tcore= 1367.8509976832215
# Vmean (m/s)= 0.7147749010353377
# distance from vent (m) = 1110.0
# phi= 0.21967756163117108
# Tcore= 1367.6537817475569
# Vmean (m/s)= 0.7101209821412615
# distance from vent (m) = 1120.0
# phi= 0.22085497482762562
# Tcore= 1367.4553413211881
# Vmean (m/s)= 0.7154709983441752
# distance from vent (m) = 1130.0
# phi= 0.22202337715811468
# Tcore= 1367.2584195800946
# Vmean (m/s)= 0.7223360394888316
# distance from vent (m) = 1140.0
# phi= 0.22318050200793624
# Tcore= 1367.0633985379898
# Vmean (m/s)= 0.7085983408435701
# distance from vent (m) = 1150.0
# phi= 0.22435948076032705
# Tcore= 1366.864694253879
# Vmean (m/s)= 0.6793349183023386
# distance from vent (m) = 1160.0
# phi= 0.2255883169794705
# Tcore= 1366.6575870259335
# Vmean (m/s)= 0.6540802805031976
# distance from vent (m) = 1170.0
# phi= 0.22686370697673947
# Tcore= 1366.4426336556073
# Vmean (m/s)= 0.6352432301873135
# distance from vent (m) = 1180.0
# phi= 0.22817612522977102
# Tcore= 1366.2214395680178
# Vmean (m/s)= 0.6377612515231699
# distance from vent (m) = 1190.0
# phi= 0.2294830298274024
# Tcore= 1366.0011747481922
# Vmean (m/s)= 0.671636284942264
# distance from vent (m) = 1200.0
# phi= 0.23072435455496265
# Tcore= 1365.7919627154572
# Vmean (m/s)= 0.7133456871770627
# distance from vent (m) = 1210.0
# phi= 0.23189358395120316
# Tcore= 1365.5949015812594
# Vmean (m/s)= 0.7427538015886107
# distance from vent (m) = 1220.0
# phi= 0.23301677255532421
# Tcore= 1365.4056001311267
# Vmean (m/s)= 0.7620220247564435
# distance from vent (m) = 1230.0
# phi= 0.23411163317395858
# Tcore= 1365.2210730605702
# Vmean (m/s)= 0.7775411077980972
# distance from vent (m) = 1240.0
# phi= 0.23518465200213595
# Tcore= 1365.0402271906528
# Vmean (m/s)= 0.7939377559790755
# distance from vent (m) = 1250.0
# phi= 0.2362355411968436
# Tcore= 1364.8631110342415
# Vmean (m/s)= 0.813528466734978
# distance from vent (m) = 1260.0
# phi= 0.23726121282547738
# Tcore= 1364.6902450294156
# Vmean (m/s)= 0.8246618299774834
# distance from vent (m) = 1270.0
# phi= 0.2382729888097927
# Tcore= 1364.5197209871153
# Vmean (m/s)= 0.8251561181809419
# distance from vent (m) = 1280.0
# phi= 0.2392839350710104
# Tcore= 1364.3493367857866
# Vmean (m/s)= 0.821011284062587
# distance from vent (m) = 1290.0
# phi= 0.24029968250291553
# Tcore= 1364.1781433983867
# Vmean (m/s)= 0.7983175787127462
# distance from vent (m) = 1300.0
# phi= 0.24134367175243449
# Tcore= 1364.0021901540858
# Vmean (m/s)= 0.7671262289063132
# distance from vent (m) = 1310.0
# phi= 0.24242929192384222
# Tcore= 1363.8192204622756
# Vmean (m/s)= 0.760509987179005
# distance from vent (m) = 1320.0
# phi= 0.24352396784140967
# Tcore= 1363.6347245211125
# Vmean (m/s)= 0.7771150824277954
# distance from vent (m) = 1330.0
# phi= 0.2445952822627894
# Tcore= 1363.4541659107676
# Vmean (m/s)= 0.7894427440607148
# distance from vent (m) = 1340.0
# phi= 0.2456498267185041
# Tcore= 1363.2764336991304
# Vmean (m/s)= 0.7898626326501338
# distance from vent (m) = 1350.0
# phi= 0.2467035663330625
# Tcore= 1363.098837134879
# Vmean (m/s)= 0.7876423656305818
# distance from vent (m) = 1360.0
# phi= 0.24775998556229065
# Tcore= 1362.9207889501777
# Vmean (m/s)= 0.7800810921386493
# distance from vent (m) = 1370.0
# phi= 0.24882625646468018
# Tcore= 1362.7410803711232
# Vmean (m/s)= 0.7704529028272502
# distance from vent (m) = 1380.0
# phi= 0.2499054203788187
# Tcore= 1362.5591988125605
# Vmean (m/s)= 0.7695941605610399
# distance from vent (m) = 1390.0
# phi= 0.2509855095114497
# Tcore= 1362.3771613182969
# Vmean (m/s)= 0.7800125463192816
# distance from vent (m) = 1400.0
# phi= 0.25205109507038903
# Tcore= 1362.1975682465657
# Vmean (m/s)= 0.7976045506898702
# distance from vent (m) = 1410.0
# phi= 0.25309322899098413
# Tcore= 1362.0219276981506
# Vmean (m/s)= 0.8120279755438079
# distance from vent (m) = 1420.0
# phi= 0.25411685401848155
# Tcore= 1361.8494066261005
# Vmean (m/s)= 0.8128049828664444
# distance from vent (m) = 1430.0
# phi= 0.2551392766278384
# Tcore= 1361.6770882087933
# Vmean (m/s)= 0.8033543753810041
# distance from vent (m) = 1440.0
# phi= 0.2561733267677859
# Tcore= 1361.502810095319
# Vmean (m/s)= 0.8017417677774487
# distance from vent (m) = 1450.0
# phi= 0.25720918688137706
# Tcore= 1361.3282269301071
# Vmean (m/s)= 0.813446134994325
# distance from vent (m) = 1460.0
# phi= 0.2582300995390045
# Tcore= 1361.1561629990463
# Vmean (m/s)= 0.8258209777154173
# distance from vent (m) = 1470.0
# phi= 0.25923568598039637
# Tcore= 1360.9866821381374
# Vmean (m/s)= 0.8359244598611876
# distance from vent (m) = 1480.0
# phi= 0.26022905689629466
# Tcore= 1360.8192600736602
# Vmean (m/s)= 0.8461763686552823
# distance from vent (m) = 1490.0
# phi= 0.2612103368402372
# Tcore= 1360.6538758134452
# Vmean (m/s)= 0.8498155591794551
# distance from vent (m) = 1500.0
# phi= 0.2621872557562593
# Tcore= 1360.4892265579358
# Vmean (m/s)= 0.8396322537124843
# distance from vent (m) = 1510.0
# phi= 0.26317563928484206
# Tcore= 1360.3226450643544
# Vmean (m/s)= 0.8259583152321187
# distance from vent (m) = 1520.0
# phi= 0.26417993584421384
# Tcore= 1360.1533815992918
# Vmean (m/s)= 0.8210450185129944
# distance from vent (m) = 1530.0
# phi= 0.26518993140043723
# Tcore= 1359.9831576291417
# Vmean (m/s)= 0.8188413253478699
# distance from vent (m) = 1540.0
# phi= 0.26620237713787076
# Tcore= 1359.8125207071023
# Vmean (m/s)= 0.816427191675427
# distance from vent (m) = 1550.0
# phi= 0.26721754393723474
# Tcore= 1359.6414251791196
# Vmean (m/s)= 0.8090761477497055
# distance from vent (m) = 1560.0
# phi= 0.2682415758413769
# Tcore= 1359.468835532354
# Vmean (m/s)= 0.785735411966058
# distance from vent (m) = 1570.0
# phi= 0.269295380448703
# Tcore= 1359.2912280142652
# Vmean (m/s)= 0.748936803138352
# distance from vent (m) = 1580.0
# phi= 0.2704000343084662
# Tcore= 1359.1050503974511
# Vmean (m/s)= 0.7145811578992225
# distance from vent (m) = 1590.0
# phi= 0.27155685808906005
# Tcore= 1358.910080097351
# Vmean (m/s)= 0.6921700606914466
# distance from vent (m) = 1600.0
# phi= 0.27275038791474915
# Tcore= 1358.7089233851564
# Vmean (m/s)= 0.674408981778496
# distance from vent (m) = 1610.0
# phi= 0.27397466476374666
# Tcore= 1358.5025845903815
# Vmean (m/s)= 0.6580569851395314
# distance from vent (m) = 1620.0
# phi= 0.27522868192348704
# Tcore= 1358.2912333836837
# Vmean (m/s)= 0.6419636612880615
# distance from vent (m) = 1630.0
# phi= 0.27651343468166667
# Tcore= 1358.0747020199456
# Vmean (m/s)= 0.6239482277828714
# distance from vent (m) = 1640.0
# phi= 0.27783451094203354
# Tcore= 1357.8520487176365
# Vmean (m/s)= 0.6082114059560978
# distance from vent (m) = 1650.0
# phi= 0.27918901740036456
# Tcore= 1357.6237611123
# Vmean (m/s)= 0.5968159422577712
# distance from vent (m) = 1660.0
# phi= 0.28056870932136097
# Tcore= 1357.3912287660646
# Vmean (m/s)= 0.5899245146617051
# distance from vent (m) = 1670.0
# phi= 0.2819639291024147
# Tcore= 1357.1560793647634
# Vmean (m/s)= 0.58760627597679
# distance from vent (m) = 1680.0
# phi= 0.28336416176774315
# Tcore= 1356.920085095326
# Vmean (m/s)= 0.5923495418442364
# distance from vent (m) = 1690.0
# phi= 0.28475285333233696
# Tcore= 1356.6860359552259
# Vmean (m/s)= 0.5961735367923153
# distance from vent (m) = 1700.0
# phi= 0.2861322937870367
# Tcore= 1356.4535459909507
# Vmean (m/s)= 0.5954085749908898
# distance from vent (m) = 1710.0
# phi= 0.28751306181405384
# Tcore= 1356.220832278532
# Vmean (m/s)= 0.6008004690955655
# distance from vent (m) = 1720.0
# phi= 0.2888811345852025
# Tcore= 1355.9902582159789
# Vmean (m/s)= 0.6150155048905639
# distance from vent (m) = 1730.0
# phi= 0.2902174860517749
# Tcore= 1355.7650304407139
# Vmean (m/s)= 0.6322573198914985
# distance from vent (m) = 1740.0
# phi= 0.29151736988524213
# Tcore= 1355.5459488957474
# Vmean (m/s)= 0.6482080487040679
# distance from vent (m) = 1750.0
# phi= 0.292785225798988
# Tcore= 1355.332265314779
# Vmean (m/s)= 0.6565460171001918
# distance from vent (m) = 1760.0
# phi= 0.29403679338775046
# Tcore= 1355.1213269571224
# Vmean (m/s)= 0.6472791085054769
# distance from vent (m) = 1770.0
# phi= 0.2953057313575182
# Tcore= 1354.9074610071616
# Vmean (m/s)= 0.6271144636208997
# distance from vent (m) = 1780.0
# phi= 0.2966146696427614
# Tcore= 1354.686853430997
# Vmean (m/s)= 0.6125040434428579
# distance from vent (m) = 1790.0
# phi= 0.29795411935220395
# Tcore= 1354.4611034799673
# Vmean (m/s)= 0.6053690461792738
# distance from vent (m) = 1800.0
# phi= 0.299308792044991
# Tcore= 1354.2327878575875
# Vmean (m/s)= 0.6022832773023723
# distance from vent (m) = 1810.0
# phi= 0.30066992363145706
# Tcore= 1354.0033836576213
# Vmean (m/s)= 0.5981298048385921
# distance from vent (m) = 1820.0
# phi= 0.30203999657774083
# Tcore= 1353.7724724868992
# Vmean (m/s)= 0.5851433019243474
# distance from vent (m) = 1830.0
# phi= 0.303439751800971
# Tcore= 1353.5365586852313
# Vmean (m/s)= 0.5610744718132474
# distance from vent (m) = 1840.0
# phi= 0.30489852645228893
# Tcore= 1353.2906977889418
# Vmean (m/s)= 0.5314980062798743
# distance from vent (m) = 1850.0
# phi= 0.30643723748089446
# Tcore= 1353.0313644695138
# Vmean (m/s)= 0.5007529719033897
# distance from vent (m) = 1860.0
# phi= 0.3080690464083096
# Tcore= 1352.756340492983
# Vmean (m/s)= 0.47674703366342913
# distance from vent (m) = 1870.0
# phi= 0.3097817316433256
# Tcore= 1352.4676856780927
# Vmean (m/s)= 0.47067221590586006
# distance from vent (m) = 1880.0
# phi= 0.311515688321592
# Tcore= 1352.1754457884972
# Vmean (m/s)= 0.47607375599377894
# distance from vent (m) = 1890.0
# phi= 0.3132294583121164
# Tcore= 1351.8866081496449
# Vmean (m/s)= 0.4732049122146415
# distance from vent (m) = 1900.0
# phi= 0.31495287903772534
# Tcore= 1351.5961439824075
# Vmean (m/s)= 0.453529439636043
# distance from vent (m) = 1910.0
# phi= 0.3167498039739287
# Tcore= 1351.2932914650698
# Vmean (m/s)= 0.4327833148481458
# distance from vent (m) = 1920.0
# phi= 0.31863148196806484
# Tcore= 1350.976154724485
# Vmean (m/s)= 0.4223774413815339
# distance from vent (m) = 1930.0
# phi= 0.3205583858921418
# Tcore= 1350.6513956361575
# Vmean (m/s)= 0.41891070120779866
# distance from vent (m) = 1940.0
# phi= 0.32250029413736453
# Tcore= 1350.3241077296593
# Vmean (m/s)= 0.4187490741459108
# distance from vent (m) = 1950.0
# phi= 0.3244421073831563
# Tcore= 1349.9968358343012
# Vmean (m/s)= 0.4181651197870771
# distance from vent (m) = 1960.0
# phi= 0.326385773901253
# Tcore= 1349.6692515896782
# Vmean (m/s)= 0.41302021780569376
# distance from vent (m) = 1970.0
# phi= 0.32835263835388806
# Tcore= 1349.3377575808072
# Vmean (m/s)= 0.4006020651427837
# distance from vent (m) = 1980.0
# phi= 0.3303791809353515
# Tcore= 1348.996205460336
# Vmean (m/s)= 0.38114317495435246
# distance from vent (m) = 1990.0
# phi= 0.33250756073865295
# Tcore= 1348.6374897631501
# Vmean (m/s)= 0.3602554114051573
# distance from vent (m) = 2000.0
# phi= 0.3347575245250487
# Tcore= 1348.2582823834205
# Vmean (m/s)= 0.34738763066173545
# distance from vent (m) = 2010.0
# phi= 0.33708918317640524
# Tcore= 1347.8653062062256
# Vmean (m/s)= 0.3463739846948363
# distance from vent (m) = 2020.0
# phi= 0.3394264179736724
# Tcore= 1347.471390229158
# Vmean (m/s)= 0.347006199475066
# distance from vent (m) = 2030.0
# phi= 0.3417582091004443
# Tcore= 1347.0783917246458
# Vmean (m/s)= 0.33950871958370726
# distance from vent (m) = 2040.0
# phi= 0.34413997558584436
# Tcore= 1346.6769704068818
# Vmean (m/s)= 0.32629969735056696
# distance from vent (m) = 2050.0
# phi= 0.34661632698332523
# Tcore= 1346.2596078118008
# Vmean (m/s)= 0.31415659155761816
# distance from vent (m) = 2060.0
# phi= 0.3491864866996271
# Tcore= 1345.8264348259072
# Vmean (m/s)= 0.3043006385300647
# distance from vent (m) = 2070.0
# phi= 0.3518379635555354
# Tcore= 1345.379556704125
# Vmean (m/s)= 0.2966652733824921
# distance from vent (m) = 2080.0
# phi= 0.3545557553684634
# Tcore= 1344.9215019041933
# Vmean (m/s)= 0.29081342327030374
# distance from vent (m) = 2090.0
# phi= 0.3573263105119008
# Tcore= 1344.4545544081084
# Vmean (m/s)= 0.28257827254891044
# distance from vent (m) = 2100.0
# phi= 0.3601754873680862
# Tcore= 1343.9743560615602
# Vmean (m/s)= 0.27001527489635635
# distance from vent (m) = 2110.0
# phi= 0.36315475468977737
# Tcore= 1343.4722323556573
# Vmean (m/s)= 0.2562265063383306
# distance from vent (m) = 2120.0
# phi= 0.3662915970244507
# Tcore= 1342.9435510632966
# Vmean (m/s)= 0.24281137367930383
# distance from vent (m) = 2130.0
# phi= 0.36959875105336554
# Tcore= 1342.3861655528053
# Vmean (m/s)= 0.22972446286288417
# distance from vent (m) = 2140.0
# phi= 0.37309103187334114
# Tcore= 1341.7975788977533
# Vmean (m/s)= 0.217324415184797
# distance from vent (m) = 2150.0
# phi= 0.376779008565669
# Tcore= 1341.1760097923047
# Vmean (m/s)= 0.20359474116688425
# distance from vent (m) = 2160.0
# phi= 0.3807116367206658
# Tcore= 1340.5132072942715
# Vmean (m/s)= 0.18870287674341016
# distance from vent (m) = 2170.0
# phi= 0.38494994643493324
# Tcore= 1339.7988854323164
# Vmean (m/s)= 0.1752099532423288
# distance from vent (m) = 2180.0
# phi= 0.3895094235999641
# Tcore= 1339.0304342247268
# Vmean (m/s)= 0.16324676221489615
# distance from vent (m) = 2190.0
# phi= 0.3943972089541875
# Tcore= 1338.2066501762622
# Vmean (m/s)= 0.15170308071431082
# distance from vent (m) = 2200.0
# phi= 0.39965032756569707
# Tcore= 1337.3212931069068
# Vmean (m/s)= 0.1415839812073483
# distance from vent (m) = 2210.0
# phi= 0.40527151141307505
# Tcore= 1336.373902570832
# Vmean (m/s)= 0.13351379964992233
# distance from vent (m) = 2220.0
# phi= 0.41122436843523086
# Tcore= 1335.3706120614797
# Vmean (m/s)= 0.12468523800821123
# distance from vent (m) = 2230.0
# phi= 0.4175895391332586
# Tcore= 1334.2978304831604
# Vmean (m/s)= 0.11347807107588416
# distance from vent (m) = 2240.0
# phi= 0.42457237611881693
# Tcore= 1333.1209478451449
# Vmean (m/s)= 0.10183736239545475
# distance from vent (m) = 2250.0
# phi= 0.43234011420619234
# Tcore= 1331.811778504576
# Vmean (m/s)= 0.09092869101125993
# distance from vent (m) = 2260.0
# phi= 0.4410235162383561
# Tcore= 1330.348283780054
# Vmean (m/s)= 0.0801143041825441
# distance from vent (m) = 2270.0
# phi= 0.4508587496365659
# Tcore= 1328.6906601736143
# Vmean (m/s)= 0.06858144544981715
# distance from vent (m) = 2280.0
# phi= 0.4623212460589945
# Tcore= 1326.7587787541038
# Vmean (m/s)= 0.05629669922069827
# distance from vent (m) = 2290.0
# phi= 0.47624756992595696
# Tcore= 1324.4116455180988
# Vmean (m/s)= 0.043924046903466865
# distance from vent (m) = 2300.0
# phi= 0.4940393396633478
# Tcore= 1321.4130326410104
# Vmean (m/s)= 0.03175851257895867
# distance from vent (m) = 2310.0
# phi= 0.5185470492816527
# Tcore= 1317.2825197839927
# Vmean (m/s)= 0.019227451544404226
# distance from vent (m) = 2320.0
# phi= 0.5588050184254608
# Tcore= 1310.497468804699
# Vmean (m/s)= 0.006730865280091181
# distance from vent (m) = 2330.0
# phi= 0.6727886627378988
# Tcore= 1291.2867422351871
# Terminated:  relative viscosity max: new phi > phimax
# ----------------------------------------- END RUN FLOWGO ---------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^ End  for 5_m3s ^^^^^^^^^^^^^^^^^^^^^^^^
# Volume conservation
# channel_depth =0.9019999999999992
# Vmean (m/s)= 2.772425400519989
# distance from vent (m) = 0.0
# phi= 0.10424406912101529
# Tcore= 1387.1088647548852
# Vmean (m/s)= 2.6891042924118436
# distance from vent (m) = 10.0
# phi= 0.10449532079611079
# Tcore= 1387.0665189669478
# Vmean (m/s)= 2.5759652319358493
# distance from vent (m) = 20.0
# phi= 0.1047570740680875
# Tcore= 1387.0224032469516
# Vmean (m/s)= 2.4411703310427613
# distance from vent (m) = 30.0
# phi= 0.10503261184312569
# Tcore= 1386.9759642961026
# Vmean (m/s)= 2.368665572069735
# distance from vent (m) = 40.0
# phi= 0.10531620378854417
# Tcore= 1386.9281679008072
# Vmean (m/s)= 2.3343574506402356
# distance from vent (m) = 50.0
# phi= 0.1056037707462413
# Tcore= 1386.8797015596224
# Vmean (m/s)= 2.1955458784595927
# distance from vent (m) = 60.0
# phi= 0.10590875101234634
# Tcore= 1386.8283003911777
# Vmean (m/s)= 2.0453897780119514
# distance from vent (m) = 70.0
# phi= 0.10623522870838942
# Tcore= 1386.773276060384
# Vmean (m/s)= 1.916870531285422
# distance from vent (m) = 80.0
# phi= 0.10658277521344965
# Tcore= 1386.7147008067222
# Vmean (m/s)= 1.851471592939412
# distance from vent (m) = 90.0
# phi= 0.10694215037335822
# Tcore= 1386.6541319595467
# Vmean (m/s)= 1.7434866210245503
# distance from vent (m) = 100.0
# phi= 0.10732301798743478
# Tcore= 1386.589940788635
# Vmean (m/s)= 1.5788125034982707
# distance from vent (m) = 110.0
# phi= 0.10774233695817578
# Tcore= 1386.5192690519932
# Vmean (m/s)= 1.4891048584758695
# distance from vent (m) = 120.0
# phi= 0.10818615875210319
# Tcore= 1386.4444676260505
# Vmean (m/s)= 1.4624568580398922
# distance from vent (m) = 130.0
# phi= 0.108637804952906
# Tcore= 1386.3683474798477
# Vmean (m/s)= 1.4175571906593674
# distance from vent (m) = 140.0
# phi= 0.10910333204654707
# Tcore= 1386.289887857324
# Vmean (m/s)= 1.3509279617422665
# distance from vent (m) = 150.0
# phi= 0.10959118154926029
# Tcore= 1386.207666031024
# Vmean (m/s)= 1.289120170114896
# distance from vent (m) = 160.0
# phi= 0.1101017947156586
# Tcore= 1386.1216076321928
# Vmean (m/s)= 1.2828933275101577
# distance from vent (m) = 170.0
# phi= 0.11061476842757682
# Tcore= 1386.035151388611
# Vmean (m/s)= 1.367814458642373
# distance from vent (m) = 180.0
# phi= 0.11109657384874001
# Tcore= 1385.9539482277407
# Vmean (m/s)= 1.4351697814678686
# distance from vent (m) = 190.0
# phi= 0.11155627250236236
# Tcore= 1385.8764709265683
# Vmean (m/s)= 1.451029462773921
# distance from vent (m) = 200.0
# phi= 0.11201102788732546
# Tcore= 1385.7998267605633
# Vmean (m/s)= 1.5118015109785674
# distance from vent (m) = 210.0
# phi= 0.11244793287540916
# Tcore= 1385.7261910884145
# Vmean (m/s)= 1.5898518055999447
# distance from vent (m) = 220.0
# phi= 0.11286392770193607
# Tcore= 1385.6560796007975
# Vmean (m/s)= 1.6095669350910071
# distance from vent (m) = 230.0
# phi= 0.113274932280185
# Tcore= 1385.5868091662612
# Vmean (m/s)= 1.5914411472176169
# distance from vent (m) = 240.0
# phi= 0.11369044375139793
# Tcore= 1385.516779143023
# Vmean (m/s)= 1.5533799381979525
# distance from vent (m) = 250.0
# phi= 0.1141158055638182
# Tcore= 1385.4450889499185
# Vmean (m/s)= 1.4911343852728427
# distance from vent (m) = 260.0
# phi= 0.11455838651479794
# Tcore= 1385.3704966548096
# Vmean (m/s)= 1.4387804522292724
# distance from vent (m) = 270.0
# phi= 0.11501659487726473
# Tcore= 1385.293270526304
# Vmean (m/s)= 1.3732265860452126
# distance from vent (m) = 280.0
# phi= 0.11549606158311182
# Tcore= 1385.2124615309365
# Vmean (m/s)= 1.3374250427640135
# distance from vent (m) = 290.0
# phi= 0.11598799223025734
# Tcore= 1385.1295518713052
# Vmean (m/s)= 1.3865600589066787
# distance from vent (m) = 300.0
# phi= 0.1164628556717672
# Tcore= 1385.0495187070057
# Vmean (m/s)= 1.455546449229838
# distance from vent (m) = 310.0
# phi= 0.11691572301667699
# Tcore= 1384.9731927499986
# Vmean (m/s)= 1.4552136406935903
# distance from vent (m) = 320.0
# phi= 0.1173686438615014
# Tcore= 1384.8968577761518
# Vmean (m/s)= 1.3814590425938313
# distance from vent (m) = 330.0
# phi= 0.11784506550603656
# Tcore= 1384.816561993365
# Vmean (m/s)= 1.3634143083639034
# distance from vent (m) = 340.0
# phi= 0.1183275833416936
# Tcore= 1384.7352387626363
# Vmean (m/s)= 1.4393992362512757
# distance from vent (m) = 350.0
# phi= 0.11878520148738643
# Tcore= 1384.658112108868
# Vmean (m/s)= 1.512935518075493
# distance from vent (m) = 360.0
# phi= 0.1192211041265168
# Tcore= 1384.584645371936
# Vmean (m/s)= 1.5664974101070193
# distance from vent (m) = 370.0
# phi= 0.11964246267295475
# Tcore= 1384.5136298865812
# Vmean (m/s)= 1.6007796533949141
# distance from vent (m) = 380.0
# phi= 0.12005500930591581
# Tcore= 1384.4440995551831
# Vmean (m/s)= 1.6089093642971268
# distance from vent (m) = 390.0
# phi= 0.12046549156543539
# Tcore= 1384.3749171518932
# Vmean (m/s)= 1.6116485215586063
# distance from vent (m) = 400.0
# phi= 0.12087525715009051
# Tcore= 1384.305855536502
# Vmean (m/s)= 1.576762501464487
# distance from vent (m) = 410.0
# phi= 0.12129378876657737
# Tcore= 1384.2353165000154
# Vmean (m/s)= 1.5232097814341767
# distance from vent (m) = 420.0
# phi= 0.12172657942442414
# Tcore= 1384.1623742543109
# Vmean (m/s)= 1.5187638442816798
# distance from vent (m) = 430.0
# phi= 0.12216055911788422
# Tcore= 1384.0892316093457
# Vmean (m/s)= 1.5574652770974995
# distance from vent (m) = 440.0
# phi= 0.12258400457449689
# Tcore= 1384.017864397557
# Vmean (m/s)= 1.5714953599167985
# distance from vent (m) = 450.0
# phi= 0.12300373335743123
# Tcore= 1383.9471235914446
# Vmean (m/s)= 1.5448029145965922
# distance from vent (m) = 460.0
# phi= 0.12343047002669578
# Tcore= 1383.8752016808944
# Vmean (m/s)= 1.5390087353637134
# distance from vent (m) = 470.0
# phi= 0.12385872676967188
# Tcore= 1383.8030235781457
# Vmean (m/s)= 1.5549734141412683
# distance from vent (m) = 480.0
# phi= 0.12428266525282126
# Tcore= 1383.731573271997
# Vmean (m/s)= 1.5873375231311204
# distance from vent (m) = 490.0
# phi= 0.12469815869899378
# Tcore= 1383.6615462866869
# Vmean (m/s)= 1.6191958796284316
# distance from vent (m) = 500.0
# phi= 0.12510566879973975
# Tcore= 1383.592864809033
# Vmean (m/s)= 1.6103206609302605
# distance from vent (m) = 510.0
# phi= 0.12551532149889222
# Tcore= 1383.5238222192881
# Vmean (m/s)= 1.634785001990253
# distance from vent (m) = 520.0
# phi= 0.125918980958456
# Tcore= 1383.4557897261031
# Vmean (m/s)= 1.701374874479952
# distance from vent (m) = 530.0
# phi= 0.12630726400671866
# Tcore= 1383.3903487629127
# Vmean (m/s)= 1.7349640301352138
# distance from vent (m) = 540.0
# phi= 0.12668822221570258
# Tcore= 1383.3261423231963
# Vmean (m/s)= 1.7271637323163083
# distance from vent (m) = 550.0
# phi= 0.12707081412402613
# Tcore= 1383.2616605408946
# Vmean (m/s)= 1.707709004017028
# distance from vent (m) = 560.0
# phi= 0.12745759682676808
# Tcore= 1383.196472444927
# Vmean (m/s)= 1.698190172162656
# distance from vent (m) = 570.0
# phi= 0.12784644696770622
# Tcore= 1383.1309359043194
# Vmean (m/s)= 1.7091872093313885
# distance from vent (m) = 580.0
# phi= 0.12823283559212292
# Tcore= 1383.0658142260468
# Vmean (m/s)= 1.7340490338764807
# distance from vent (m) = 590.0
# phi= 0.1286138178936127
# Tcore= 1383.0016037257956
# Vmean (m/s)= 1.7273783141447256
# distance from vent (m) = 600.0
# phi= 0.12899619239661203
# Tcore= 1382.9371585848407
# Vmean (m/s)= 1.6902320745043762
# distance from vent (m) = 610.0
# phi= 0.12938667860768235
# Tcore= 1382.871346302076
# Vmean (m/s)= 1.672198298597788
# distance from vent (m) = 620.0
# phi= 0.129781214096429
# Tcore= 1382.8048515567816
# Vmean (m/s)= 1.663223336652929
# distance from vent (m) = 630.0
# phi= 0.13017777912143288
# Tcore= 1382.7380147548147
# Vmean (m/s)= 1.6500266680245106
# distance from vent (m) = 640.0
# phi= 0.13057738552760448
# Tcore= 1382.670665360516
# Vmean (m/s)= 1.6430268338384824
# distance from vent (m) = 650.0
# phi= 0.13097860738650546
# Tcore= 1382.6030436989035
# Vmean (m/s)= 1.6671250221696259
# distance from vent (m) = 660.0
# phi= 0.13137416168757599
# Tcore= 1382.536377243667
# Vmean (m/s)= 1.731293075120671
# distance from vent (m) = 670.0
# phi= 0.13175545310119824
# Tcore= 1382.4721146458655
# Vmean (m/s)= 1.7881682994821178
# distance from vent (m) = 680.0
# phi= 0.13212495539274552
# Tcore= 1382.4098389787507
# Vmean (m/s)= 1.7990942638943106
# distance from vent (m) = 690.0
# phi= 0.13249225289587896
# Tcore= 1382.3479349051888
# Vmean (m/s)= 1.7818372145128227
# distance from vent (m) = 700.0
# phi= 0.13286296299320002
# Tcore= 1382.2854556753032
# Vmean (m/s)= 1.7651887137198015
# distance from vent (m) = 710.0
# phi= 0.13323702719500055
# Tcore= 1382.2224111469097
# Vmean (m/s)= 1.7564183083615434
# distance from vent (m) = 720.0
# phi= 0.1336128682834027
# Tcore= 1382.1590671432464
# Vmean (m/s)= 1.750550496220759
# distance from vent (m) = 730.0
# phi= 0.13398989713150714
# Tcore= 1382.0955229553635
# Vmean (m/s)= 1.7163210430325995
# distance from vent (m) = 740.0
# phi= 0.13437417909197866
# Tcore= 1382.0307563328122
# Vmean (m/s)= 1.6560427922702805
# distance from vent (m) = 750.0
# phi= 0.13477198868944812
# Tcore= 1381.963709771441
# Vmean (m/s)= 1.630233233460967
# distance from vent (m) = 760.0
# phi= 0.13517587449466192
# Tcore= 1381.8956391301128
# Vmean (m/s)= 1.627308773091029
# distance from vent (m) = 770.0
# phi= 0.13558042730192818
# Tcore= 1381.8274560727084
# Vmean (m/s)= 1.6153681306368053
# distance from vent (m) = 780.0
# phi= 0.13598784617371054
# Tcore= 1381.7587899707225
# Vmean (m/s)= 1.619618547967368
# distance from vent (m) = 790.0
# phi= 0.13639418805930442
# Tcore= 1381.690305383263
# Vmean (m/s)= 1.6255818688253034
# distance from vent (m) = 800.0
# phi= 0.13679904391752304
# Tcore= 1381.6220712498553
# Vmean (m/s)= 1.6219310707568177
# distance from vent (m) = 810.0
# phi= 0.13720474678512912
# Tcore= 1381.5536943620564
# Vmean (m/s)= 1.6157697709600098
# distance from vent (m) = 820.0
# phi= 0.13761191401659145
# Tcore= 1381.4850706713605
# Vmean (m/s)= 1.6094027739899774
# distance from vent (m) = 830.0
# phi= 0.13802060745042305
# Tcore= 1381.4161897555462
# Vmean (m/s)= 1.609753571829551
# distance from vent (m) = 840.0
# phi= 0.13842917568013927
# Tcore= 1381.347329941549
# Vmean (m/s)= 1.6265914187337471
# distance from vent (m) = 850.0
# phi= 0.1388335967194732
# Tcore= 1381.2791690922231
# Vmean (m/s)= 1.6610950671024494
# distance from vent (m) = 860.0
# phi= 0.13922982167353842
# Tcore= 1381.212389605583
# Vmean (m/s)= 1.6903126598340812
# distance from vent (m) = 870.0
# phi= 0.13961936284301457
# Tcore= 1381.1467365994915
# Vmean (m/s)= 1.7110916295145608
# distance from vent (m) = 880.0
# phi= 0.14000427980785213
# Tcore= 1381.0818629537323
# Vmean (m/s)= 1.7643988671693869
# distance from vent (m) = 890.0
# phi= 0.14037788478793778
# Tcore= 1381.0188958222573
# Vmean (m/s)= 1.8869120584309982
# distance from vent (m) = 900.0
# phi= 0.140727955151657
# Tcore= 1380.9598951991586
# Vmean (m/s)= 2.0479357062417622
# distance from vent (m) = 910.0
# phi= 0.1410513849063174
# Tcore= 1380.9053845663507
# Vmean (m/s)= 2.1748949328980633
# distance from vent (m) = 920.0
# phi= 0.14135658672949106
# Tcore= 1380.853946056827
# Vmean (m/s)= 2.2766465825058217
# distance from vent (m) = 930.0
# phi= 0.14164864353257567
# Tcore= 1380.8047230001273
# Vmean (m/s)= 2.407071655661925
# distance from vent (m) = 940.0
# phi= 0.14192548196691374
# Tcore= 1380.7580648370365
# Vmean (m/s)= 2.5357356085510205
# distance from vent (m) = 950.0
# phi= 0.1421888413809928
# Tcore= 1380.7136784189333
# Vmean (m/s)= 2.6202657335015904
# distance from vent (m) = 960.0
# phi= 0.14244406044286748
# Tcore= 1380.6706639703027
# Vmean (m/s)= 2.661770215880863
# distance from vent (m) = 970.0
# phi= 0.14269546413911255
# Tcore= 1380.6282925608232
# Vmean (m/s)= 2.66256203676655
# distance from vent (m) = 980.0
# phi= 0.14294678140676334
# Tcore= 1380.5859357179606
# Vmean (m/s)= 2.627308468364867
# distance from vent (m) = 990.0
# phi= 0.14320130117978017
# Tcore= 1380.5430391270027
# Vmean (m/s)= 2.547290142514904
# distance from vent (m) = 1000.0
# phi= 0.1434634386623734
# Tcore= 1380.4988586524082
# Vmean (m/s)= 2.4091914441191578
# distance from vent (m) = 1010.0
# phi= 0.14373992469210198
# Tcore= 1380.4522598833528
# Vmean (m/s)= 2.2462730367209023
# distance from vent (m) = 1020.0
# phi= 0.14403560806600302
# Tcore= 1380.4024256068526
# Vmean (m/s)= 2.1308074475151155
# distance from vent (m) = 1030.0
# phi= 0.14434666700849988
# Tcore= 1380.3499999423868
# Vmean (m/s)= 2.0834514826867165
# distance from vent (m) = 1040.0
# phi= 0.14466451049587623
# Tcore= 1380.296430815301
# Vmean (m/s)= 2.054062395964341
# distance from vent (m) = 1050.0
# phi= 0.14498671235477345
# Tcore= 1380.242127131217
# Vmean (m/s)= 2.0404425260097216
# distance from vent (m) = 1060.0
# phi= 0.14531096331268983
# Tcore= 1380.187478093366
# Vmean (m/s)= 2.085445631373052
# distance from vent (m) = 1070.0
# phi= 0.1456284420227264
# Tcore= 1380.133970445607
# Vmean (m/s)= 2.1615441546278444
# distance from vent (m) = 1080.0
# phi= 0.14593512695429045
# Tcore= 1380.0822819739951
# Vmean (m/s)= 2.195241135731751
# distance from vent (m) = 1090.0
# phi= 0.1462372594277079
# Tcore= 1380.0313607706103
# Vmean (m/s)= 2.1879271413004364
# distance from vent (m) = 1100.0
# phi= 0.14654034180003225
# Tcore= 1379.980279471904
# Vmean (m/s)= 2.1788818394110203
# distance from vent (m) = 1110.0
# phi= 0.14684461281842603
# Tcore= 1379.9289978395905
# Vmean (m/s)= 2.1834706014796277
# distance from vent (m) = 1120.0
# phi= 0.14714824684823416
# Tcore= 1379.8778235649038
# Vmean (m/s)= 2.2182182765748912
# distance from vent (m) = 1130.0
# phi= 0.14744728359342354
# Tcore= 1379.8274241134675
# Vmean (m/s)= 2.2579103181501035
# distance from vent (m) = 1140.0
# phi= 0.14774124519955908
# Tcore= 1379.7778800225458
# Vmean (m/s)= 2.2351124047932616
# distance from vent (m) = 1150.0
# phi= 0.14803806720185678
# Tcore= 1379.7278538423832
# Vmean (m/s)= 2.164433773910719
# distance from vent (m) = 1160.0
# phi= 0.14834418447325826
# Tcore= 1379.6762610438325
# Vmean (m/s)= 2.1057091562054304
# distance from vent (m) = 1170.0
# phi= 0.14865849506164505
# Tcore= 1379.6232873491606
# Vmean (m/s)= 2.0666871785787326
# distance from vent (m) = 1180.0
# phi= 0.14897849919851128
# Tcore= 1379.5693540676664
# Vmean (m/s)= 2.0949856690472757
# distance from vent (m) = 1190.0
# phi= 0.1492943126409143
# Tcore= 1379.5161270829917
# Vmean (m/s)= 2.2238020254346327
# distance from vent (m) = 1200.0
# phi= 0.14959247659930366
# Tcore= 1379.4658747304543
# Vmean (m/s)= 2.3790692472293333
# distance from vent (m) = 1210.0
# phi= 0.1498719115518643
# Tcore= 1379.4187789519328
# Vmean (m/s)= 2.4956944871484894
# distance from vent (m) = 1220.0
# phi= 0.15013880702716453
# Tcore= 1379.3737965684552
# Vmean (m/s)= 2.580084689379267
# distance from vent (m) = 1230.0
# phi= 0.15039733146063966
# Tcore= 1379.3302250347235
# Vmean (m/s)= 2.652822631781537
# distance from vent (m) = 1240.0
# phi= 0.15064906605573145
# Tcore= 1379.2877978557756
# Vmean (m/s)= 2.729122806805593
# distance from vent (m) = 1250.0
# phi= 0.1508940680951769
# Tcore= 1379.2465053772173
# Vmean (m/s)= 2.8168023996750513
# distance from vent (m) = 1260.0
# phi= 0.1511317860514419
# Tcore= 1379.2064405531278
# Vmean (m/s)= 2.8765947565578855
# distance from vent (m) = 1270.0
# phi= 0.15136478719780047
# Tcore= 1379.1671706969998
# Vmean (m/s)= 2.900635327089818
# distance from vent (m) = 1280.0
# phi= 0.151595938998598
# Tcore= 1379.128212528326
# Vmean (m/s)= 2.908998983585987
# distance from vent (m) = 1290.0
# phi= 0.15182644626087852
# Tcore= 1379.0893629897394
# Vmean (m/s)= 2.853298804988231
# distance from vent (m) = 1300.0
# phi= 0.15206121731697478
# Tcore= 1379.0497948342174
# Vmean (m/s)= 2.7676128921040064
# distance from vent (m) = 1310.0
# phi= 0.152302889497655
# Tcore= 1379.0090635678107
# Vmean (m/s)= 2.7678031928092124
# distance from vent (m) = 1320.0
# phi= 0.15254453187329367
# Tcore= 1378.9683373247256
# Vmean (m/s)= 2.8504780045449394
# distance from vent (m) = 1330.0
# phi= 0.1527794834796394
# Tcore= 1378.9287387393863
# Vmean (m/s)= 2.918594730025861
# distance from vent (m) = 1340.0
# phi= 0.15300920509078797
# Tcore= 1378.8900216139118
# Vmean (m/s)= 2.944387728791091
# distance from vent (m) = 1350.0
# phi= 0.15323700171523041
# Tcore= 1378.851628924399
# Vmean (m/s)= 2.9608752462544827
# distance from vent (m) = 1360.0
# phi= 0.1534635809747235
# Tcore= 1378.813441408754
# Vmean (m/s)= 2.9580052557397396
# distance from vent (m) = 1370.0
# phi= 0.1536903566446513
# Tcore= 1378.7752207902267
# Vmean (m/s)= 2.947566781282338
# distance from vent (m) = 1380.0
# phi= 0.15391788261639747
# Tcore= 1378.736873716337
# Vmean (m/s)= 2.9698366659314948
# distance from vent (m) = 1390.0
# phi= 0.15414377558343753
# Tcore= 1378.6988018679594
# Vmean (m/s)= 3.0347906985633006
# distance from vent (m) = 1400.0
# phi= 0.1543650656311771
# Tcore= 1378.6615057924978
# Vmean (m/s)= 3.127569181085012
# distance from vent (m) = 1410.0
# phi= 0.15458011752916265
# Tcore= 1378.6252610905901
# Vmean (m/s)= 3.2090644399308346
# distance from vent (m) = 1420.0
# phi= 0.15478998618271048
# Tcore= 1378.5898899692056
# Vmean (m/s)= 3.238688650920135
# distance from vent (m) = 1430.0
# phi= 0.15499802862474962
# Tcore= 1378.5548266362778
# Vmean (m/s)= 3.228892649229177
# distance from vent (m) = 1440.0
# phi= 0.1552066572219837
# Tcore= 1378.5196645131484
# Vmean (m/s)= 3.249831900098364
# distance from vent (m) = 1450.0
# phi= 0.1554140043546504
# Tcore= 1378.4847183671934
# Vmean (m/s)= 3.3236616861280592
# distance from vent (m) = 1460.0
# phi= 0.15561698780757768
# Tcore= 1378.45050767288
# Vmean (m/s)= 3.4008466745093764
# distance from vent (m) = 1470.0
# phi= 0.15581561229745183
# Tcore= 1378.4170316352606
# Vmean (m/s)= 3.4696107004413084
# distance from vent (m) = 1480.0
# phi= 0.15601051572152203
# Tcore= 1378.3841827435633
# Vmean (m/s)= 3.5396080589357006
# distance from vent (m) = 1490.0
# phi= 0.15620177999620768
# Tcore= 1378.35194719165
# Vmean (m/s)= 3.583248269211844
# distance from vent (m) = 1500.0
# phi= 0.15639084406497752
# Tcore= 1378.3200824609585
# Vmean (m/s)= 3.57044313949691
# distance from vent (m) = 1510.0
# phi= 0.15658053678965467
# Tcore= 1378.2881117770241
# Vmean (m/s)= 3.5431550504031217
# distance from vent (m) = 1520.0
# phi= 0.15677159433025334
# Tcore= 1378.2559110679344
# Vmean (m/s)= 3.5523960345864936
# distance from vent (m) = 1530.0
# phi= 0.15696217544325242
# Tcore= 1378.2237906556313
# Vmean (m/s)= 3.573243866361002
# distance from vent (m) = 1540.0
# phi= 0.15715170188807775
# Tcore= 1378.191847996391
# Vmean (m/s)= 3.593469552922814
# distance from vent (m) = 1550.0
# phi= 0.15734021659523295
# Tcore= 1378.1600758547356
# Vmean (m/s)= 3.592785959106135
# distance from vent (m) = 1560.0
# phi= 0.15752875632132327
# Tcore= 1378.1282994964058
# Vmean (m/s)= 3.5230164016717884
# distance from vent (m) = 1570.0
# phi= 0.1577207967558367
# Tcore= 1378.0959331310385
# Vmean (m/s)= 3.394010852420593
# distance from vent (m) = 1580.0
# phi= 0.15791969657456364
# Tcore= 1378.06241068968
# Vmean (m/s)= 3.274727161292678
# distance from vent (m) = 1590.0
# phi= 0.1581254183790194
# Tcore= 1378.0277384754459
# Vmean (m/s)= 3.207593534441534
# distance from vent (m) = 1600.0
# phi= 0.15833519789516962
# Tcore= 1377.9923823772183
# Vmean (m/s)= 3.160838329954321
# distance from vent (m) = 1610.0
# phi= 0.15854790177194397
# Tcore= 1377.9565334092226
# Vmean (m/s)= 3.1201499694699617
# distance from vent (m) = 1620.0
# phi= 0.15876322029344075
# Tcore= 1377.9202437707681
# Vmean (m/s)= 3.08036980009436
# distance from vent (m) = 1630.0
# phi= 0.15898116148439265
# Tcore= 1377.8835121093718
# Vmean (m/s)= 3.031388186383569
# distance from vent (m) = 1640.0
# phi= 0.15920242905429915
# Tcore= 1377.846219822309
# Vmean (m/s)= 2.9927235842577207
# distance from vent (m) = 1650.0
# phi= 0.15942639659960547
# Tcore= 1377.8084724832124
# Vmean (m/s)= 2.9744136019454186
# distance from vent (m) = 1660.0
# phi= 0.15965166077631032
# Tcore= 1377.7705066107342
# Vmean (m/s)= 2.9777224081993805
# distance from vent (m) = 1670.0
# phi= 0.15987667507248363
# Tcore= 1377.7325828529522
# Vmean (m/s)= 3.00350921420416
# distance from vent (m) = 1680.0
# phi= 0.1600998429175672
# Tcore= 1377.694970294792
# Vmean (m/s)= 3.0645897731962464
# distance from vent (m) = 1690.0
# phi= 0.16031877726753715
# Tcore= 1377.6580712470443
# Vmean (m/s)= 3.1219734372433665
# distance from vent (m) = 1700.0
# phi= 0.1605338846401178
# Tcore= 1377.6218171954858
# Vmean (m/s)= 3.157014270427264
# distance from vent (m) = 1710.0
# phi= 0.16074671925668926
# Tcore= 1377.585946192693
# Vmean (m/s)= 3.2241480971456467
# distance from vent (m) = 1720.0
# phi= 0.16095534743286513
# Tcore= 1377.5507841405285
# Vmean (m/s)= 3.3379549613643458
# distance from vent (m) = 1730.0
# phi= 0.16115723835030465
# Tcore= 1377.5167575814096
# Vmean (m/s)= 3.4691239952566906
# distance from vent (m) = 1740.0
# phi= 0.1613519138328787
# Tcore= 1377.4839471068185
# Vmean (m/s)= 3.5951008382045946
# distance from vent (m) = 1750.0
# phi= 0.1615401546395522
# Tcore= 1377.4522211281658
# Vmean (m/s)= 3.681788246195702
# distance from vent (m) = 1760.0
# phi= 0.16172422064233982
# Tcore= 1377.4211987681454
# Vmean (m/s)= 3.6740237950851506
# distance from vent (m) = 1770.0
# phi= 0.161908643471279
# Tcore= 1377.390116268886
# Vmean (m/s)= 3.6064846831510295
# distance from vent (m) = 1780.0
# phi= 0.16209630018182522
# Tcore= 1377.3584887334007
# Vmean (m/s)= 3.5692149422327772
# distance from vent (m) = 1790.0
# phi= 0.162285789826883
# Tcore= 1377.3265522763684
# Vmean (m/s)= 3.573764123036006
# distance from vent (m) = 1800.0
# phi= 0.1624750438691238
# Tcore= 1377.294655527676
# Vmean (m/s)= 3.601642604129758
# distance from vent (m) = 1810.0
# phi= 0.16266291166219463
# ...
# Vmean (m/s)= 9.433640828007695
# distance from vent (m) = 14810.0
# phi= 0.24010425726920134
# Tcore= 1364.2110802355257
# Vmean (m/s)= 9.430060856357956
# distance from vent (m) = 14820.0
# phi= 0.24015503686975778
# Tcore= 1364.2025218758813
# Vmean (m/s)= 9.42644827017422
# distance from vent (m) = 14830.0
# phi= 0.24020583248878166
# Tcore= 1364.1939608164953
# Vmean (m/s)= 9.42280309902735
# distance from vent (m) = 14840.0
# phi= 0.24025664428953458
# Tcore= 1364.1853970298516
# Vmean (m/s)= 9.419125372593335
# distance from vent (m) = 14850.0
# phi= 0.24030747243549608
# Tcore= 1364.1768304883974
# Vmean (m/s)= 9.415415120653366
# distance from vent (m) = 14860.0
# phi= 0.24035831709036667
# Tcore= 1364.1682611645429
# Vmean (m/s)= 9.411672373093847
# distance from vent (m) = 14870.0
# phi= 0.24040917841807083
# Tcore= 1364.15968903066
# Vmean (m/s)= 9.407897159906307
# distance from vent (m) = 14880.0
# phi= 0.24046005658276007
# Tcore= 1364.1511140590833
# Vmean (m/s)= 9.404089511187477
# distance from vent (m) = 14890.0
# phi= 0.24051095174881593
# Tcore= 1364.1425362221075
# Vmean (m/s)= 9.400249457139063
# distance from vent (m) = 14900.0
# phi= 0.24056186408085312
# Tcore= 1364.133955491989
# Vmean (m/s)= 9.396377028067942
# distance from vent (m) = 14910.0
# phi= 0.24061279374372244
# Tcore= 1364.1253718409434
# Vmean (m/s)= 9.392472254385961
# distance from vent (m) = 14920.0
# phi= 0.24066374090251397
# Tcore= 1364.1167852411472
# Vmean (m/s)= 9.388535166610113
# distance from vent (m) = 14930.0
# phi= 0.2407147057225601
# Tcore= 1364.108195664735
# Vmean (m/s)= 9.384565795362187
# distance from vent (m) = 14940.0
# phi= 0.24076568836943857
# Tcore= 1364.0996030838003
# Vmean (m/s)= 9.38056417136908
# distance from vent (m) = 14950.0
# phi= 0.24081668900897565
# Tcore= 1364.0910074703952
# Vmean (m/s)= 9.376530325462582
# distance from vent (m) = 14960.0
# phi= 0.24086770780724914
# Tcore= 1364.0824087965289
# Vmean (m/s)= 9.372464288579367
# distance from vent (m) = 14970.0
# phi= 0.24091874493059157
# Tcore= 1364.0738070341677
# Vmean (m/s)= 9.368366091760945
# distance from vent (m) = 14980.0
# phi= 0.24096980054559325
# Tcore= 1364.0652021552348
# Vmean (m/s)= 9.364235766153815
# distance from vent (m) = 14990.0
# phi= 0.24102087481910542
# Tcore= 1364.0565941316092
# Vmean (m/s)= 9.3600733430091
# distance from vent (m) = 15000.0
# phi= 0.24107196791824342
# Tcore= 1364.0479829351252
# Vmean (m/s)= 9.35587885368277
# distance from vent (m) = 15010.0
# phi= 0.24112308001038982
# Tcore= 1364.0393685375725
# Vmean (m/s)= 9.351652329635609
# distance from vent (m) = 15020.0
# phi= 0.2411742112631975
# Tcore= 1364.030750910695
# Vmean (m/s)= 9.347393802433078
# distance from vent (m) = 15030.0
# phi= 0.24122536184459292
# Tcore= 1364.02213002619
# Vmean (m/s)= 9.343103303745238
# distance from vent (m) = 15040.0
# phi= 0.24127653192277929
# Tcore= 1364.0135058557094
# Vmean (m/s)= 9.338780865346916
# distance from vent (m) = 15050.0
# phi= 0.24132772166623967
# Tcore= 1364.0048783708564
# Vmean (m/s)= 9.334426519117486
# distance from vent (m) = 15060.0
# phi= 0.24137893124374024
# Tcore= 1363.9962475431878
# Vmean (m/s)= 9.330040297040945
# distance from vent (m) = 15070.0
# phi= 0.2414301608243335
# Tcore= 1363.9876133442115
# Vmean (m/s)= 9.325622231205864
# distance from vent (m) = 15080.0
# phi= 0.24148141057736142
# Tcore= 1363.9789757453866
# Vmean (m/s)= 9.321172353805283
# distance from vent (m) = 15090.0
# phi= 0.2415326806724588
# Tcore= 1363.970334718123
# Vmean (m/s)= 9.316690697136696
# distance from vent (m) = 15100.0
# phi= 0.2415839712795564
# Tcore= 1363.9616902337807
# Vmean (m/s)= 9.312177293602142
# distance from vent (m) = 15110.0
# phi= 0.24163528256888417
# Tcore= 1363.9530422636692
# Vmean (m/s)= 9.307632175707967
# distance from vent (m) = 15120.0
# phi= 0.24168661471097463
# Tcore= 1363.9443907790471
# Vmean (m/s)= 9.303055376065016
# distance from vent (m) = 15130.0
# phi= 0.24173796787666607
# Tcore= 1363.9357357511217
# Vmean (m/s)= 9.298446927388415
# distance from vent (m) = 15140.0
# phi= 0.2417893422371058
# Tcore= 1363.9270771510476
# Vmean (m/s)= 9.293806862497553
# distance from vent (m) = 15150.0
# phi= 0.2418407379637535
# Tcore= 1363.9184149499272
# Vmean (m/s)= 9.289135214316147
# distance from vent (m) = 15160.0
# phi= 0.24189215522838453
# Tcore= 1363.9097491188095
# Vmean (m/s)= 9.284432015872113
# distance from vent (m) = 15170.0
# phi= 0.24194359420309322
# Tcore= 1363.90107962869
# Vmean (m/s)= 9.279697300297611
# distance from vent (m) = 15180.0
# phi= 0.2419950550602962
# Tcore= 1363.8924064505097
# Vmean (m/s)= 9.274931100828951
# distance from vent (m) = 15190.0
# phi= 0.2420465379727358
# Tcore= 1363.8837295551548
# Vmean (m/s)= 9.27013345080651
# distance from vent (m) = 15200.0
# phi= 0.24209804311348326
# Tcore= 1363.8750489134559
# Vmean (m/s)= 9.26530438367482
# distance from vent (m) = 15210.0
# phi= 0.24214957065594234
# Tcore= 1363.8663644961875
# Vmean (m/s)= 9.260443932982389
# distance from vent (m) = 15220.0
# phi= 0.24220112077385247
# Tcore= 1363.857676274068
# Vmean (m/s)= 9.255552132381776
# distance from vent (m) = 15230.0
# phi= 0.24225269364129226
# Tcore= 1363.8489842177578
# Vmean (m/s)= 9.2506290156295
# distance from vent (m) = 15240.0
# phi= 0.2423042894326829
# Tcore= 1363.8402882978605
# Vmean (m/s)= 9.245674616586019
# distance from vent (m) = 15250.0
# phi= 0.24235590832279155
# Tcore= 1363.8315884849208
# Vmean (m/s)= 9.240688969215638
# distance from vent (m) = 15260.0
# phi= 0.2424075504867348
# Tcore= 1363.8228847494247
# Vmean (m/s)= 9.235672107586593
# distance from vent (m) = 15270.0
# phi= 0.24245921609998208
# Tcore= 1363.8141770617988
# Vmean (m/s)= 9.230624065870856
# distance from vent (m) = 15280.0
# phi= 0.2425109053383592
# Tcore= 1363.8054653924094
# Vmean (m/s)= 9.225544878344182
# distance from vent (m) = 15290.0
# phi= 0.2425626183780517
# Tcore= 1363.7967497115624
# Vmean (m/s)= 9.2204345793861
# distance from vent (m) = 15300.0
# phi= 0.2426143553956085
# Tcore= 1363.7880299895023
# Vmean (m/s)= 9.215293203479762
# distance from vent (m) = 15310.0
# phi= 0.24266611656794523
# Tcore= 1363.7793061964119
# Vmean (m/s)= 9.210120785211968
# distance from vent (m) = 15320.0
# phi= 0.2427179020723479
# Tcore= 1363.7705783024114
# Vmean (m/s)= 9.20491735927318
# distance from vent (m) = 15330.0
# phi= 0.2427697120864763
# Tcore= 1363.7618462775583
# Vmean (m/s)= 9.199682960457364
# distance from vent (m) = 15340.0
# phi= 0.2428215467883677
# Tcore= 1363.7531100918463
# Vmean (m/s)= 9.194417623662066
# distance from vent (m) = 15350.0
# phi= 0.24287340635644025
# Tcore= 1363.7443697152048
# Vmean (m/s)= 9.189121383888192
# distance from vent (m) = 15360.0
# phi= 0.2429252909694967
# Tcore= 1363.7356251174988
# Vmean (m/s)= 9.183794276240272
# distance from vent (m) = 15370.0
# phi= 0.24297720080672783
# Tcore= 1363.7268762685273
# Vmean (m/s)= 9.178436335926056
# distance from vent (m) = 15380.0
# phi= 0.24302913604771623
# Tcore= 1363.7181231380237
# Vmean (m/s)= 9.173047598256685
# distance from vent (m) = 15390.0
# phi= 0.2430810968724398
# Tcore= 1363.7093656956545
# Vmean (m/s)= 9.16762809864665
# distance from vent (m) = 15400.0
# phi= 0.24313308346127552
# Tcore= 1363.7006039110192
# Vmean (m/s)= 9.162177872613652
# distance from vent (m) = 15410.0
# phi= 0.24318509599500288
# Tcore= 1363.6918377536495
# Vmean (m/s)= 9.156696955778655
# distance from vent (m) = 15420.0
# phi= 0.24323713465480779
# Tcore= 1363.6830671930081
# Vmean (m/s)= 9.151185383865739
# distance from vent (m) = 15430.0
# phi= 0.24328919962228615
# Tcore= 1363.6742921984894
# Vmean (m/s)= 9.145643192702185
# distance from vent (m) = 15440.0
# phi= 0.24334129107944755
# Tcore= 1363.6655127394172
# Vmean (m/s)= 9.140070418218237
# distance from vent (m) = 15450.0
# phi= 0.24339340920871905
# Tcore= 1363.6567287850455
# Vmean (m/s)= 9.134467096447306
# distance from vent (m) = 15460.0
# phi= 0.24344555419294883
# Tcore= 1363.6479403045573
# Vmean (m/s)= 9.128833263525683
# distance from vent (m) = 15470.0
# phi= 0.24349772621541002
# Tcore= 1363.639147267064
# Vmean (m/s)= 9.12316895569274
# distance from vent (m) = 15480.0
# phi= 0.24354992545980447
# Tcore= 1363.6303496416042
# Vmean (m/s)= 9.117474209290581
# distance from vent (m) = 15490.0
# phi= 0.24360215211026648
# Tcore= 1363.6215473971442
# Vmean (m/s)= 9.111749060764259
# distance from vent (m) = 15500.0
# phi= 0.24365440635136665
# Tcore= 1363.6127405025768
# Vmean (m/s)= 9.105993546661631
# distance from vent (m) = 15510.0
# phi= 0.2437066883681157
# Tcore= 1363.6039289267203
# Vmean (m/s)= 9.100207703633327
# distance from vent (m) = 15520.0
# phi= 0.24375899834596834
# Tcore= 1363.5951126383181
# Vmean (m/s)= 9.094391568432608
# distance from vent (m) = 15530.0
# phi= 0.24381133647082703
# Tcore= 1363.5862916060387
# Vmean (m/s)= 9.08854517791548
# distance from vent (m) = 15540.0
# phi= 0.243863702929046
# Tcore= 1363.5774657984737
# Vmean (m/s)= 9.082668569040532
# distance from vent (m) = 15550.0
# phi= 0.24391609790743504
# Tcore= 1363.5686351841384
# Vmean (m/s)= 9.076761778868915
# distance from vent (m) = 15560.0
# phi= 0.2439685215932635
# Tcore= 1363.5597997314708
# Vmean (m/s)= 9.070824844564342
# distance from vent (m) = 15570.0
# phi= 0.2440209741742641
# Tcore= 1363.5509594088303
# Vmean (m/s)= 9.064857803392941
# distance from vent (m) = 15580.0
# phi= 0.24407345583863704
# Tcore= 1363.5421141844977
# Vmean (m/s)= 9.058860692723304
# distance from vent (m) = 15590.0
# phi= 0.24412596677505388
# Tcore= 1363.5332640266747
# Vmean (m/s)= 9.052833550026435
# distance from vent (m) = 15600.0
# phi= 0.24417850717266154
# Tcore= 1363.5244089034825
# Vmean (m/s)= 9.046776412875579
# distance from vent (m) = 15610.0
# phi= 0.24423107722108636
# Tcore= 1363.5155487829613
# Vmean (m/s)= 9.040689318946264
# distance from vent (m) = 15620.0
# phi= 0.24428367711043808
# Tcore= 1363.5066836330707
# Vmean (m/s)= 9.034572306016361
# distance from vent (m) = 15630.0
# phi= 0.24433630703131393
# Tcore= 1363.4978134216872
# Vmean (m/s)= 9.028425411965795
# distance from vent (m) = 15640.0
# phi= 0.24438896717480266
# Tcore= 1363.488938116605
# Vmean (m/s)= 9.0222486747767
# distance from vent (m) = 15650.0
# phi= 0.2444416577324887
# Tcore= 1363.4800576855341
# Vmean (m/s)= 9.016042132533165
# distance from vent (m) = 15660.0
# phi= 0.24449437889645623
# Tcore= 1363.4711720961013
# Vmean (m/s)= 9.009805823421491
# distance from vent (m) = 15670.0
# phi= 0.24454713085929333
# Tcore= 1363.4622813158478
# Vmean (m/s)= 9.003539785729822
# distance from vent (m) = 15680.0
# phi= 0.24459991381409618
# Tcore= 1363.4533853122293
# Vmean (m/s)= 8.997244057848325
# distance from vent (m) = 15690.0
# phi= 0.24465272795447315
# Tcore= 1363.4444840526153
# Vmean (m/s)= 8.990918678268942
# distance from vent (m) = 15700.0
# phi= 0.24470557347454908
# Tcore= 1363.435577504288
# Vmean (m/s)= 8.984563685585549
# distance from vent (m) = 15710.0
# phi= 0.24475845056896944
# Tcore= 1363.4266656344419
# Vmean (m/s)= 8.97817911849367
# distance from vent (m) = 15720.0
# phi= 0.2448113594329047
# Tcore= 1363.417748410183
# Vmean (m/s)= 8.971765015790668
# distance from vent (m) = 15730.0
# phi= 0.24486430026205439
# Tcore= 1363.4088257985286
# Vmean (m/s)= 8.965321416375525
# distance from vent (m) = 15740.0
# phi= 0.2449172732526516
# Tcore= 1363.3998977664055
# Vmean (m/s)= 8.958848359248838
# distance from vent (m) = 15750.0
# phi= 0.24497027860146722
# Tcore= 1363.39096428065
# Vmean (m/s)= 8.952345883512816
# distance from vent (m) = 15760.0
# phi= 0.2450233165058142
# Tcore= 1363.3820253080073
# Vmean (m/s)= 8.945814028371126
# distance from vent (m) = 15770.0
# phi= 0.24507638716355198
# Tcore= 1363.3730808151302
# Vmean (m/s)= 8.939252833128943
# distance from vent (m) = 15780.0
# phi= 0.24512949077309096
# Tcore= 1363.3641307685787
# Vmean (m/s)= 8.932662337192856
# distance from vent (m) = 15790.0
# phi= 0.24518262753339673
# Tcore= 1363.3551751348193
# Vmean (m/s)= 8.926042580070822
# distance from vent (m) = 15800.0
# phi= 0.24523579764399464
# Tcore= 1363.3462138802242
# Vmean (m/s)= 8.919393601372066
# distance from vent (m) = 15810.0
# phi= 0.2452890013049742
# Tcore= 1363.3372469710703
# Vmean (m/s)= 8.912715440807014
# distance from vent (m) = 15820.0
# phi= 0.24534223871699354
# Tcore= 1363.328274373539
# Vmean (m/s)= 8.906008138187387
# distance from vent (m) = 15830.0
# phi= 0.245395510081284
# Tcore= 1363.3192960537147
# Vmean (m/s)= 8.899271733426083
# distance from vent (m) = 15840.0
# phi= 0.24544881559965456
# Tcore= 1363.310311977585
# Vmean (m/s)= 8.892506266537035
# distance from vent (m) = 15850.0
# phi= 0.2455021554744965
# Tcore= 1363.3013221110384
# Vmean (m/s)= 8.885711777635194
# distance from vent (m) = 15860.0
# phi= 0.2455555299087879
# Tcore= 1363.2923264198657
# Vmean (m/s)= 8.87888830693651
# distance from vent (m) = 15870.0
# phi= 0.24560893910609827
# Tcore= 1363.2833248697573
# Vmean (m/s)= 8.872035894757934
# distance from vent (m) = 15880.0
# phi= 0.2456623832705932
# Tcore= 1363.274317426303
# Vmean (m/s)= 8.86515458151717
# distance from vent (m) = 15890.0
# phi= 0.24571586260703904
# Tcore= 1363.265304054992
# Vmean (m/s)= 8.858244407732917
# distance from vent (m) = 15900.0
# phi= 0.2457693773208075
# Tcore= 1363.2562847212107
# Vmean (m/s)= 8.851305414024432
# distance from vent (m) = 15910.0
# phi= 0.2458229276178805
# Tcore= 1363.2472593902432
# Vmean (m/s)= 8.844337641111897
# distance from vent (m) = 15920.0
# phi= 0.24587651370485478
# Tcore= 1363.23822802727
# Vmean (m/s)= 8.837341129816018
# distance from vent (m) = 15930.0
# phi= 0.24593013578894676
# Tcore= 1363.2291905973668
# Vmean (m/s)= 8.830315921058206
# distance from vent (m) = 15940.0
# phi= 0.24598379407799728
# Tcore= 1363.2201470655043
# Vmean (m/s)= 8.823262055860303
# distance from vent (m) = 15950.0
# phi= 0.24603748878047646
# Tcore= 1363.211097396547
# Vmean (m/s)= 8.81617957534481
# distance from vent (m) = 15960.0
# phi= 0.24609122010548853
# Tcore= 1363.202041555253
# Vmean (m/s)= 8.809068520734481
# distance from vent (m) = 15970.0
# phi= 0.24614498826277675
# Tcore= 1363.1929795062717
# Vmean (m/s)= 8.801928933352666
# distance from vent (m) = 15980.0
# phi= 0.24619879346272827
# Tcore= 1363.1839112141452
# Vmean (m/s)= 8.794760854622842
# distance from vent (m) = 15990.0
# phi= 0.24625263591637908
# Tcore= 1363.174836643305
# Terminated: Reached maximum channel length.
# ----------------------------------------- END RUN FLOWGO ---------------------------------------------
# ^^^^^^^^^^^^^^^^^^^^^^ End  for 30_m3s ^^^^^^^^^^^^^^^^^^^^^^^^
# effusion_rate_init_plot =  5.0
# run_out_distance_plot =  2330.0
# effusion_rate_init_plot =  10.0
# run_out_distance_plot =  5350.0
# effusion_rate_init_plot =  15.0
# run_out_distance_plot =  6920.0
# effusion_rate_init_plot =  20.0
# run_out_distance_plot =  10230.0
# effusion_rate_init_plot =  25.0
# run_out_distance_plot =  15990.0
# effusion_rate_init_plot =  30.0
# run_out_distance_plot =  15990.0
# ******************************  End of the eruption rates loop ******************************
# ----------- Vent file is saved as shape file in:'/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/vent_pixel_center.shp'---------------
#    Unnamed: 0  Effusion Rate     Median X      Median Y  25th Percentile X  \
# 0           0              5  371064.1800  7.647482e+06        371064.1800
# 1           1             10  373899.8700  7.646787e+06        373899.8700
# 2           2             15  375235.8900  7.646672e+06        375235.8900
# 3           3             20  375850.1994  7.646548e+06        375850.1994
# 4           4             25  375850.1994  7.646548e+06        375850.1994
#
#    25th Percentile Y  75th Percentile X  75th Percentile Y    Average X  \
# 0       7.647482e+06        371064.1800       7.647482e+06  371064.1800
# 1       7.646787e+06        373899.8700       7.646787e+06  373899.8700
# 2       7.646672e+06        375235.8900       7.646672e+06  375235.8900
# 3       7.646548e+06        375850.1994       7.646548e+06  375850.1994
# 4       7.646548e+06        375850.1994       7.646548e+06  375850.1994
#
#       Average Y    +2sigma X     +2sigma Y    -2sigma X     -2sigma Y
# 0  7.647482e+06  371064.1800  7.647482e+06  371064.1800  7.647482e+06
# 1  7.646787e+06  373899.8700  7.646787e+06  373899.8700  7.646787e+06
# 2  7.646672e+06  375235.8900  7.646672e+06  375235.8900  7.646672e+06
# 3  7.646548e+06  375850.1994  7.646548e+06  375850.1994  7.646548e+06
# 4  7.646548e+06  375850.1994  7.646548e+06  375850.1994  7.646548e+06
# ----------- Runouts coordinates are saved as shape file in:'/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/runouts_pixel_center.shp'---------------

# %%
# [mapping]
config.mapping_display = "yes"

config.img_tif_map_background_path = "./assets/test/map_background/HS_srtm_48_17_utm.tif"
config.monitoring_network_path =  "./assets/test/monitoring_stations/example_monitoring_stations.shp"
config.lava_flow_outline_path = "./assets/test/lavaflow_outline/example_lavaflow_outline.shp"
config.logo_path = "./assets/logo/all_logo.png"
config.source_img_tif_map_background = "©credit"
config.unverified_data = "NON VALIDES NE PAS DIFFUSER"
config.set_map_layers()
# Out:
# {'img_tif_map_background': '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/map_background/HS_srtm_48_17_utm.tif',
#  'monitoring_network_path': '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/monitoring_stations/example_monitoring_stations.shp',
#  'lava_flow_outline_path': '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/lavaflow_outline/example_lavaflow_outline.shp',
#  'logo_path': '/Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/logo/all_logo.png',
#  'source_img_tif_map_background': '©credit',
#  'unverified_data': 'NON VALIDES NE PAS DIFFUSER'}

# %%
# Map parameter
print("Display: " + config.mapping_display)
config.show(config.map_layers)
# Out:
# Display: yes
# img_tif_map_background: /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/map_background/HS_srtm_48_17_utm.tif
# monitoring_network_path: /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/monitoring_stations/example_monitoring_stations.shp
# lava_flow_outline_path: /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/test/lavaflow_outline/example_lavaflow_outline.shp
# logo_path: /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/logo/all_logo.png
# source_img_tif_map_background: ©credit
# unverified_data: NON VALIDES NE PAS DIFFUSER

# %%
# Make the map
mapping = Mapping(path_to_folder = runner.path_to_folder, 
                    dem = config.dem,
                    flow_id = config.name_vent,
                    map_layers = config.map_layers,
                    sim_layers = runner.sim_layers,
                    mode = config.mode,
                    language = config.language,
                    grid_mode = config.grid_mode)
mapping.create_map(display = config.mapping_display)
# Out:
# /Users/chevrel/anaconda3/envs/new_env_downflowgo/lib/python3.8/site-packages/shapely/measurement.py:72: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
# Map created /Users/chevrel/Documents/GitHub/DOWNFLOWGO/./assets/outputs/pixel_center/map_pixel_center.png

# %%
print("************************************** THE END *************************************")

runtime(start_time, time.time())
# Out:
# ************************************** THE END *************************************
# The code took 8 minutes and 40 seconds to execute.
